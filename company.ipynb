# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
company_Telangana=pd.read_csv('company_master_data_upto_Mar_2015_Telangana.csv', encoding='latin-1')
company_Bihar=pd.read_csv('company_master_data_upto_Mar_2015_Bihar.csv')
company_west_bengal=pd.read_csv('company_master_data_upto_Mar_2015_West_Bengal.csv')
company_uttarakhand=pd.read_csv('company_master_data_upto_Mar_2015_Uttarakhand.csv')
company_uttarpradesh=pd.read_csv('company_master_data_upto_Mar_2015_Uttar_Pradesh.csv')
company_tripura=pd.read_csv('company_master_data_upto_Mar_2015_Tripura.csv')

# %%
company=pd.concat([company_Telangana,company_Bihar,company_west_bengal,company_uttarakhand,company_uttarpradesh,company_tripura],axis=0)

# %%
company.shape
# Out:
# (351924, 16)

# %%
company[company.DATE_OF_REGISTRATION.isnull()]['DATE_OF_REGISTRATION']
# Out:
# 3231      NaN
# 37255     NaN
# 41733     NaN
# 11636     NaN
# 184994    NaN
# Name: DATE_OF_REGISTRATION, dtype: object

# %%
company['YEAR']=pd.to_datetime(company['DATE_OF_REGISTRATION'])

# %%
company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 351924 entries, 0 to 332
# Data columns (total 17 columns):
#  AUTHORIZED_CAPITAL                       76945 non-null object
#  PAIDUP_CAPITAL                           63256 non-null object
# AUTHORIZED_CAPITAL                        274174 non-null object
# COMPANY_CATEGORY                          351924 non-null object
# COMPANY_CLASS                             351924 non-null object
# COMPANY_NAME                              351924 non-null object
# COMPANY_STATUS                            351924 non-null object
# CORPORATE_IDENTIFICATION_NUMBER           351924 non-null object
# DATE_OF_REGISTRATION                      351919 non-null object
# PAIDUP_CAPITAL                            266805 non-null object
# PRINCIPAL_BUSINESS_ACTIVITY               329653 non-null object
# PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN    17050 non-null object
# REGISTERED_OFFICE_ADDRESS                 351924 non-null object
# ...

# %%
company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 351924 entries, 0 to 332
# Data columns (total 17 columns):
#  AUTHORIZED_CAPITAL                       76945 non-null object
#  PAIDUP_CAPITAL                           63256 non-null object
# AUTHORIZED_CAPITAL                        274174 non-null object
# COMPANY_CATEGORY                          351924 non-null object
# COMPANY_CLASS                             351924 non-null object
# COMPANY_NAME                              351924 non-null object
# COMPANY_STATUS                            351924 non-null object
# CORPORATE_IDENTIFICATION_NUMBER           351924 non-null object
# DATE_OF_REGISTRATION                      351919 non-null object
# PAIDUP_CAPITAL                            266805 non-null object
# PRINCIPAL_BUSINESS_ACTIVITY               329653 non-null object
# PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN    17050 non-null object
# REGISTERED_OFFICE_ADDRESS                 351924 non-null object
# ...

# %%
company[company['YEAR'].isnull()]
# Out:
#         AUTHORIZED_CAPITAL   PAIDUP_CAPITAL  AUTHORIZED_CAPITAL  \
# 3231             500,000.00        20,000.00                NaN
# 37255          1,500,000.00       242,000.00                NaN
# 41733                   NaN              NaN                NaN
# 11636                   NaN              NaN         100,000.00
# 184994                  NaN              NaN                NaN
#
#                     COMPANY_CATEGORY COMPANY_CLASS  \
# 3231       Company Limited by Shares       Private
# 37255      Company Limited by Shares       Private
# 41733   Company Limited by Guarantee        Public
# 11636      Company Limited by Shares       Private
# 184994  Company Limited by Guarantee       Private
#
#                                      COMPANY_NAME COMPANY_STATUS  \
# 3231           GAUTHAM AGRO FARMS PRIVATE LIMITED         ACTIVE
# 37255       GUARD MARKETING ENTERPRISES PVT. LTD.         ACTIVE
# 41733        MAHESH GRAHA NIRMAN ASSOCIATION LTD.         ACTIVE
# ...

# %%
company.dropna(subset=['YEAR'],inplace=True)

# %%
company[company['YEAR'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ AUTHORIZED_CAPITAL ,  PAIDUP_CAPITAL , AUTHORIZED_CAPITAL, COMPANY_CATEGORY, COMPANY_CLASS, COMPANY_NAME, COMPANY_STATUS, CORPORATE_IDENTIFICATION_NUMBER, DATE_OF_REGISTRATION, PAIDUP_CAPITAL, PRINCIPAL_BUSINESS_ACTIVITY, PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN, REGISTERED_OFFICE_ADDRESS, REGISTERED_STATE, REGISTRAR_OF_COMPANIES, SUB_CATEGORY, YEAR]
# Index: []

# %%
##company['company_year'] = pd.to_datetime(company['DATE_OF_REGISTRATION'])

# %%
company['YEAR']=company['YEAR'].apply(lambda x : x.year)

# %%
#company['company_year']=company['company_year'].apply(lambda x : x[2])

# %%
company.head()
# Out:
#    AUTHORIZED_CAPITAL   PAIDUP_CAPITAL  AUTHORIZED_CAPITAL  \
# 0        67,500,000.00    38,809,000.00                NaN
# 1        17,000,000.00         7,000.00                NaN
# 2       150,000,000.00   112,999,000.00                NaN
# 3        60,000,000.00    52,960,000.00                NaN
# 4        70,000,000.00    48,750,750.00                NaN
#
#             COMPANY_CATEGORY COMPANY_CLASS                      COMPANY_NAME  \
# 0  Company Limited by Shares        Public               ASIAN FLORA LIMITED
# 1  Company Limited by Shares        Public  JAGADISH EDIBLE OIL REFINERY LTD
# 2  Company Limited by Shares        Public          REGENT AGRO PRODUCTS LTD
# 3  Company Limited by Shares        Public    NATURITE AGRO PRODUCTS LIMITED
# 4  Company Limited by Shares        Public         FARMTEK AGRO EXPORTS LTD.
#
#   COMPANY_STATUS CORPORATE_IDENTIFICATION_NUMBER DATE_OF_REGISTRATION  \
# 0         ACTIVE           L01110TG1994PLC018562           19-10-1994
# ...

# %%
company.YEAR.value_counts().max
# Out:
# <bound method Series.max of 2012    31931
# 2011    26972
# 2010    25519
# 2013    24800
# 2014    17953
# 2008    17830
# 2009    15903
# 2007    15093
# 1995    14306
# 1996    11123
# 2005    11039
# 2006    10134
# 1994     9160
# 1997     7964
# 2004     7064
# 1993     6499
# 1991     6098
# 1992     5921
# 1998     5377
# 1999     5328
# 2000     5311
# 2003     4979
# 1990     4908
# 2015     4895
# 1989     4801
# 1988     4696
# 2002     4072
# 2001     3668
# 1987     3625
# 1986     3520
#         ...
# 1907       13
# 1901       11
# 1905        9
# 1906        9
# 1903        5
# 1904        5
# 1893        4
# 1895        4
# 1894        4
# 1879        3
# 1889        3
# 1890        3
# 1891        3
# 1902        3
# 1898        3
# 1874        3
# 1876        2
# 1885        2
# 1882        2
# 1896        2
# 1897        2
# 1899        2
# 1863        2
# 1883        1
# 1887        1
# 1881        1
# 1888        1
# 1878        1
# 1873        1
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.countplot(x=company.YEAR)

# %%
sns.countplot(y=company.YEAR)

# %%
state_companies=company.REGISTERED_STATE.value_counts().to_frame().reset_index()

# %%
state_companies
# Out:
#            index  REGISTERED_STATE
# 0    West Bengal            185051
# 1      Telangana             77037
# 2  Uttar Pradesh             65165
# 3          Bihar             19668
# 4    Uttarakhand              4665
# 5        Tripura               333

# %%
state_companies.columns=['STATE','NO OF COMPANIES']

# %%
sns.barplot(state_companies['NO OF COMPANIES'],state_companies['STATE'])

# %%
company.head()
# Out:
#    AUTHORIZED_CAPITAL   PAIDUP_CAPITAL  AUTHORIZED_CAPITAL  \
# 0        67,500,000.00    38,809,000.00                NaN
# 1        17,000,000.00         7,000.00                NaN
# 2       150,000,000.00   112,999,000.00                NaN
# 3        60,000,000.00    52,960,000.00                NaN
# 4        70,000,000.00    48,750,750.00                NaN
#
#             COMPANY_CATEGORY COMPANY_CLASS                      COMPANY_NAME  \
# 0  Company Limited by Shares        Public               ASIAN FLORA LIMITED
# 1  Company Limited by Shares        Public  JAGADISH EDIBLE OIL REFINERY LTD
# 2  Company Limited by Shares        Public          REGENT AGRO PRODUCTS LTD
# 3  Company Limited by Shares        Public    NATURITE AGRO PRODUCTS LIMITED
# 4  Company Limited by Shares        Public         FARMTEK AGRO EXPORTS LTD.
#
#   COMPANY_STATUS CORPORATE_IDENTIFICATION_NUMBER DATE_OF_REGISTRATION  \
# 0         ACTIVE           L01110TG1994PLC018562           19-10-1994
# ...

# %%
year_ncompanies=company.YEAR.value_counts().to_frame().reset_index()

# %%
company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 351919 entries, 0 to 332
# Data columns (total 17 columns):
#  AUTHORIZED_CAPITAL                       76943 non-null object
#  PAIDUP_CAPITAL                           63254 non-null object
# AUTHORIZED_CAPITAL                        274173 non-null object
# COMPANY_CATEGORY                          351919 non-null object
# COMPANY_CLASS                             351919 non-null object
# COMPANY_NAME                              351919 non-null object
# COMPANY_STATUS                            351919 non-null object
# CORPORATE_IDENTIFICATION_NUMBER           351919 non-null object
# DATE_OF_REGISTRATION                      351919 non-null object
# PAIDUP_CAPITAL                            266804 non-null object
# PRINCIPAL_BUSINESS_ACTIVITY               329650 non-null object
# PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN    17049 non-null object
# REGISTERED_OFFICE_ADDRESS                 351919 non-null object
# ...

# %%
company.head()
# Out:
#    AUTHORIZED_CAPITAL   PAIDUP_CAPITAL  AUTHORIZED_CAPITAL  \
# 0        67,500,000.00    38,809,000.00                NaN
# 1        17,000,000.00         7,000.00                NaN
# 2       150,000,000.00   112,999,000.00                NaN
# 3        60,000,000.00    52,960,000.00                NaN
# 4        70,000,000.00    48,750,750.00                NaN
#
#             COMPANY_CATEGORY COMPANY_CLASS                      COMPANY_NAME  \
# 0  Company Limited by Shares        Public               ASIAN FLORA LIMITED
# 1  Company Limited by Shares        Public  JAGADISH EDIBLE OIL REFINERY LTD
# 2  Company Limited by Shares        Public          REGENT AGRO PRODUCTS LTD
# 3  Company Limited by Shares        Public    NATURITE AGRO PRODUCTS LIMITED
# 4  Company Limited by Shares        Public         FARMTEK AGRO EXPORTS LTD.
#
#   COMPANY_STATUS CORPORATE_IDENTIFICATION_NUMBER DATE_OF_REGISTRATION  \
# 0         ACTIVE           L01110TG1994PLC018562           19-10-1994
# ...

# %%
year_ncompanies
# Out:
#      index   YEAR
# 0     2012  31931
# 1     2011  26972
# 2     2010  25519
# 3     2013  24800
# 4     2014  17953
# 5     2008  17830
# 6     2009  15903
# 7     2007  15093
# 8     1995  14306
# 9     1996  11123
# 10    2005  11039
# 11    2006  10134
# 12    1994   9160
# 13    1997   7964
# 14    2004   7064
# 15    1993   6499
# 16    1991   6098
# 17    1992   5921
# 18    1998   5377
# 19    1999   5328
# 20    2000   5311
# 21    2003   4979
# 22    1990   4908
# 23    2015   4895
# 24    1989   4801
# 25    1988   4696
# 26    2002   4072
# 27    2001   3668
# 28    1987   3625
# 29    1986   3520
# ..     ...    ...
# 109   1907     13
# 110   1901     11
# 111   1905      9
# 112   1906      9
# 113   1903      5
# 114   1904      5
# 115   1893      4
# 116   1895      4
# 117   1894      4
# 118   1879      3
# 119   1889      3
# 120   1890      3
# 121   1891      3
# 122   1902      3
# 123   1898      3
# 124   1874      3
# 125   1876      2
# 126   1885      2
# ...

# %%
year_ncompanies.columns=['YEAR','NO OF COMPANIES']

# %%
plt.hexbin(year_ncompanies['YEAR'],year_ncompanies['NO OF COMPANIES'],gridsize=10,bins=10)

# %%
company.COMPANY_STATUS.value_counts()
# Out:
# ACTIVE                                              253402
# STRIKE OFF                                           59473
# DORMANT                                              23622
# UNDER PROCESS OF STRIKING OFF                         8116
# AMALGAMATED                                           4559
# UNDER LIQUIDATION                                     1145
# DISSOLVED                                              633
# CONVERTED TO LLP AND DISSOLVED                         551
# CONVERTED TO LLP                                       285
# LIQUIDATED                                              64
# ACTIVE IN PROGRESS                                      35
# Dormant under section 455 of Companies Act, 2013        34
# Name: COMPANY_STATUS, dtype: int64

# %%
company.groupby(['REGISTERED_STATE','COMPANY_STATUS']).groups
# Out:
# {('Bihar',
#   'ACTIVE'): Int64Index([    0,     2,     3,     6,     7,     8,     9,    10,    11,
#                 12,
#              ...
#              19649, 19651, 19652, 19654, 19657, 19658, 19659, 19662, 19663,
#              19664],
#             dtype='int64', length=12652),
#  ('Bihar',
#   'ACTIVE IN PROGRESS'): Int64Index([3809, 5160, 5773, 7311, 7500, 18542], dtype='int64'),
#  ('Bihar', 'AMALGAMATED'): Int64Index([154, 896, 5884, 12254], dtype='int64'),
#  ('Bihar', 'CONVERTED TO LLP'): Int64Index([4975, 19049], dtype='int64'),
#  ('Bihar',
#   'CONVERTED TO LLP AND DISSOLVED'): Int64Index([2263, 3381], dtype='int64'),
#  ('Bihar',
#   'DISSOLVED'): Int64Index([ 1229,  3153,  3154,  3717,  4589,  5121,  5845,  6522, 13649,
#              13650, 13651, 13652, 14351, 19515],
#             dtype='int64'),
#  ('Bihar',
#   'DORMANT'): Int64Index([    1,     4,     5,    13,    26,    44,    45,    47,    53,
#                 54,
#              ...
# ...

# %%
len(company.PRINCIPAL_BUSINESS_ACTIVITY.value_counts())
# Out:
# 19

# %%
PRINCIPAL_BUSINESS_ACTIVITY_TOATAL=company.PRINCIPAL_BUSINESS_ACTIVITY.value_counts().to_frame().reset_index()

# %%
PRINCIPAL_BUSINESS_ACTIVITY_TOATAL.columns=['PRINCIPAL_BUSINESS_ACTIVITY','count']
PRINCIPAL_BUSINESS_ACTIVITY_TOATAL
# Out:
#                           PRINCIPAL_BUSINESS_ACTIVITY  count
# 0                                             Trading  77476
# 1                                   Business Services  63700
# 2                                        Construction  30198
# 3                             Real Estate and Renting  29553
# 4   Manufacturing (Metals & Chemicals, and product...  27961
# 5                                             Finance  22075
# 6               Community, personal & Social Services  14544
# 7              Manufacturing (Machinery & Equipments)  12171
# 8                   Agriculture and Allied Activities  10946
# 9                         Manufacturing (Food stuffs)  10112
# 10              Transport, storage and Communications   7435
# 11                           Manufacturing (Textiles)   6982
# 12  Manufacturing (Paper & Paper products, Publish...   4779
# 13                 Electricity, Gas & Water companies   3692
# ...

# %%
company.head()
# Out:
#    AUTHORIZED_CAPITAL   PAIDUP_CAPITAL  AUTHORIZED_CAPITAL  \
# 0        67,500,000.00    38,809,000.00                NaN
# 1        17,000,000.00         7,000.00                NaN
# 2       150,000,000.00   112,999,000.00                NaN
# 3        60,000,000.00    52,960,000.00                NaN
# 4        70,000,000.00    48,750,750.00                NaN
#
#             COMPANY_CATEGORY COMPANY_CLASS                      COMPANY_NAME  \
# 0  Company Limited by Shares        Public               ASIAN FLORA LIMITED
# 1  Company Limited by Shares        Public  JAGADISH EDIBLE OIL REFINERY LTD
# 2  Company Limited by Shares        Public          REGENT AGRO PRODUCTS LTD
# 3  Company Limited by Shares        Public    NATURITE AGRO PRODUCTS LIMITED
# 4  Company Limited by Shares        Public         FARMTEK AGRO EXPORTS LTD.
#
#   COMPANY_STATUS CORPORATE_IDENTIFICATION_NUMBER DATE_OF_REGISTRATION  \
# 0         ACTIVE           L01110TG1994PLC018562           19-10-1994
# ...

# %%
company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 351919 entries, 0 to 332
# Data columns (total 17 columns):
#  AUTHORIZED_CAPITAL                       76943 non-null object
#  PAIDUP_CAPITAL                           63254 non-null object
# AUTHORIZED_CAPITAL                        274173 non-null object
# COMPANY_CATEGORY                          351919 non-null object
# COMPANY_CLASS                             351919 non-null object
# COMPANY_NAME                              351919 non-null object
# COMPANY_STATUS                            351919 non-null object
# CORPORATE_IDENTIFICATION_NUMBER           351919 non-null object
# DATE_OF_REGISTRATION                      351919 non-null object
# PAIDUP_CAPITAL                            266804 non-null object
# PRINCIPAL_BUSINESS_ACTIVITY               329650 non-null object
# PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN    17049 non-null object
# REGISTERED_OFFICE_ADDRESS                 351919 non-null object
# ...

# %%
company_state_group=company.groupby(['REGISTERED_STATE'])

# %%
company_state_group_df=company_state_group.PRINCIPAL_BUSINESS_ACTIVITY.value_counts().to_frame()

# %%
company_state_group_df.columns=['count']

# %%
company_state_group_df[company_state_group_df.REGISTERED_STATE=='Bihar']
# Out:
# Empty DataFrame
# Columns: [REGISTERED_STATE, PRINCIPAL_BUSINESS_ACTIVITY, count]
# Index: []

# %%
company_state_group_df.reset_index(inplace=True)

# %%
company_state_group_df[company_state_group_df.REGISTERED_STATE=='Bihar']
# Out:
# Empty DataFrame
# Columns: [REGISTERED_STATE, PRINCIPAL_BUSINESS_ACTIVITY, count]
# Index: []

# %%
plt_fig=company_state_group_df.T.plot.bar()
plt_fig.legend(loc='center left',bbox_to_anchor=(1,0.5))

# %%
company.PRINCIPAL_BUSINESS_ACTIVITY.unique()
# Out:
# array(['Agriculture and Allied Activities', nan, 'Mining & Quarrying',
#        'Manufacturing (Food stuffs)', 'Manufacturing (Textiles)',
#        'Manufacturing (Leather & products thereof)',
#        'Manufacturing (Wood Products)',
#        'Manufacturing (Paper & Paper products, Publishing, printing and reproduction of recorded media)',
#        'Manufacturing (Metals & Chemicals, and products thereof)',
#        'Manufacturing (Machinery & Equipments)', 'Manufacturing (Others)',
#        'Electricity, Gas & Water companies', 'Construction', 'Trading',
#        'Transport, storage and Communications', 'Finance',
#        'Real Estate and Renting', 'Business Services',
#        'Community, personal & Social Services', 'Insurance'], dtype=object)

# %%
state_list=['Telangana', 'Bihar', 'West Bengal', 'Uttarakhand', 'Uttar Pradesh',
       'Tripura']
Business_list=['Agriculture and Allied Activities','Mining & Quarrying',
       'Manufacturing (Food stuffs)', 'Manufacturing (Textiles)',
       'Manufacturing (Leather & products thereof)',
       'Manufacturing (Wood Products)',
       'Manufacturing (Paper & Paper products, Publishing, printing and reproduction of recorded media)',
       'Manufacturing (Metals & Chemicals, and products thereof)',
       'Manufacturing (Machinery & Equipments)', 'Manufacturing (Others)',
       'Electricity, Gas & Water companies', 'Construction', 'Trading',
       'Transport, storage and Communications', 'Finance',
       'Real Estate and Renting', 'Business Services',
       'Community, personal & Social Services', 'Insurance']

# %%
df_state_business=pd.DataFrame({'Telangana':np.zeros(19), 'Bihar':np.zeros(19), 'West Bengal':np.zeros(19), 'Uttarakhand':np.zeros(19), 'Uttar Pradesh':np.zeros(19),
       'Tripura':np.zeros(19)},index=Business_list)

# %%
df_state_business
# Out:
#                                                     Bihar  Telangana  Tripura  \
# Agriculture and Allied Activities                     0.0        0.0      0.0
# Mining & Quarrying                                    0.0        0.0      0.0
# Manufacturing (Food stuffs)                           0.0        0.0      0.0
# Manufacturing (Textiles)                              0.0        0.0      0.0
# Manufacturing (Leather & products thereof)            0.0        0.0      0.0
# Manufacturing (Wood Products)                         0.0        0.0      0.0
# Manufacturing (Paper & Paper products, Publishi...    0.0        0.0      0.0
# Manufacturing (Metals & Chemicals, and products...    0.0        0.0      0.0
# Manufacturing (Machinery & Equipments)                0.0        0.0      0.0
# Manufacturing (Others)                                0.0        0.0      0.0
# Electricity, Gas & Water companies                    0.0        0.0      0.0
# ...

# %%
company_state_group_df
# Out:
#    REGISTERED_STATE                        PRINCIPAL_BUSINESS_ACTIVITY  count
# 0         Telangana                                  Business Services  22654
# 1         Telangana  Manufacturing (Metals & Chemicals, and product...   8201
# 2         Telangana                                       Construction   7647
# 3         Telangana                                            Finance   5969
# 4         Telangana                                            Trading   5107
# 5         Telangana              Community, personal & Social Services   4915
# 6         Telangana                  Agriculture and Allied Activities   4197
# 7         Telangana             Manufacturing (Machinery & Equipments)   3684
# 8         Telangana                            Real Estate and Renting   2904
# 9         Telangana                 Electricity, Gas & Water companies   2605
# 10        Telangana                        Manufacturing (Food stuffs)   2063
# ...

# %%
for item in range(0,94):
    state=company_state_group_df.loc[item,'REGISTERED_STATE']
    Activity=company_state_group_df.loc[item,'PRINCIPAL_BUSINESS_ACTIVITY']
    count=company_state_group_df.loc[item,'count']
    df_state_business.loc[''+Activity,''+state]=count
df_state_business
# Out:
#                                                     Bihar  Telangana  Tripura  \
# Agriculture and Allied Activities                     0.0     4197.0     25.0
# Mining & Quarrying                                    0.0     1537.0      2.0
# Manufacturing (Food stuffs)                           0.0     2063.0     17.0
# Manufacturing (Textiles)                              0.0     1229.0      5.0
# Manufacturing (Leather & products thereof)            0.0       92.0      0.0
# Manufacturing (Wood Products)                         0.0      156.0      6.0
# Manufacturing (Paper & Paper products, Publishi...    0.0     1236.0      6.0
# Manufacturing (Metals & Chemicals, and products...    0.0     8201.0     39.0
# Manufacturing (Machinery & Equipments)                0.0     3684.0      5.0
# Manufacturing (Others)                                0.0      321.0      1.0
# Electricity, Gas & Water companies                    0.0     2605.0      7.0
# ...

# %%
company[company.REGISTERED_STATE=='bihar']
# Out:
# Empty DataFrame
# Columns: [ AUTHORIZED_CAPITAL ,  PAIDUP_CAPITAL , AUTHORIZED_CAPITAL, COMPANY_CATEGORY, COMPANY_CLASS, COMPANY_NAME, COMPANY_STATUS, CORPORATE_IDENTIFICATION_NUMBER, DATE_OF_REGISTRATION, PAIDUP_CAPITAL, PRINCIPAL_BUSINESS_ACTIVITY, PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN, REGISTERED_OFFICE_ADDRESS, REGISTERED_STATE, REGISTRAR_OF_COMPANIES, SUB_CATEGORY, YEAR]
# Index: []

# %%
a=df_state_business.apply(np.log10)
fig=a.T.plot(kind='bar', linewidth=50,figsize=(14,10))
fig.legend(loc='center left',bbox_to_anchor=(1,0.5))

# %%
a=df_state_business.apply(np.log10)
fig=a.plot(kind='bar', linewidth=50,figsize=(14,10),color=['red','yellow','blue','orange','skyblue','m'])
fig.legend(loc='center left',bbox_to_anchor=(1,0.5))

# %%
plt.stackplot(df_state_business)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-161-9a928759620a> in <module>()
# ----> 1 plt.stackplot(df_state_business)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in stackplot(x, *args, **kwargs)
#    3446                       mplDeprecation)
#    3447     try:
# -> 3448         ret = ax.stackplot(x, *args, **kwargs)
#    3449     finally:
#    3450         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in stackplot(self, x, *args, **kwargs)
# ...
