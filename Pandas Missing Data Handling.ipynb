# %% [markdown]
# # Agenda
# * Introduction Missing Data
# * Check for Missing Values [ isnull(), notnull()]
# * Handling Missing value [ dropna(), fillna(), replace()]

# %% [markdown]
# ##  Introduction Missing Data

# %%
import pandas as pd
import numpy as np
from IPython.display import display

raw_data =  pd.DataFrame({'Date':['01/08/2017','02/08/2017','02/08/2017','02/08/2017','02/08/2017',
                                 '01/08/2017','03/07/2017','04/07/2017',np.nan],
                        'StartupName':['TouchKin','Ethinos','Leverage Edu','Zepo','Click2Clunic','Billion Loans',
                                      'Ecolobriumenergy','Droom',np.nan],
                        'IndustryVertical':['Technology','TEchnology',np.nan,'ConsumeInternet','Consumer Internet',np.nan,np.nan,'eCommerce',np.nan],
                        'SubVerical':['Predicitve Care Platform','Digital Marketing Agency',
                                      'Online Platform for Higher Education Service',np.nan,np.nan,'Peer to Peer Lenading Platform',
                                      'Energy Management Solutions Provider','Online Marketplace for Automobiles',np.nan],
                        'CityLocation':['Bangalore','Mumbai','New Delhi','Mumbai','Hyderabad',np.nan,'Ahmedabad',np.nan,np.nan],
                        'AmountInUSD':[1300000,np.nan,np.nan,500000,850000,1000000,2600000,20000000,np.nan],
                         'InvestorsName':['People Group (Shaadi.com)','Hillhouse Capital, Tybourne Capital','Kalaari Capital, Sequoia Capital',
                                         'Asia Pacific Internet Group','KARSEMVEN Fund','Exfinity Fund, GrowX Ventures','MakeMyTrip',
                                         'UK based Group of Angel Investors',np.nan]},
columns = ['Date','StartupName','IndustryVertical','SubVerical','CityLocation','AmountInUSD','InvestorsName'])

display(raw_data)
# Out:
#          Date       StartupName   IndustryVertical  \
# 0  01/08/2017          TouchKin         Technology
# 1  02/08/2017           Ethinos         TEchnology
# 2  02/08/2017      Leverage Edu                NaN
# 3  02/08/2017              Zepo    ConsumeInternet
# 4  02/08/2017      Click2Clunic  Consumer Internet
# 5  01/08/2017     Billion Loans                NaN
# 6  03/07/2017  Ecolobriumenergy                NaN
# 7  04/07/2017             Droom          eCommerce
# 8         NaN               NaN                NaN
#
#                                      SubVerical CityLocation  AmountInUSD  \
# 0                      Predicitve Care Platform    Bangalore    1300000.0
# 1                      Digital Marketing Agency       Mumbai          NaN
# 2  Online Platform for Higher Education Service    New Delhi          NaN
# 3                                           NaN       Mumbai     500000.0
# 4                                           NaN    Hyderabad     850000.0
# 5                Peer to Peer Lenading Platform          NaN    1000000.0
# 6          Energy Management Solutions Provider    Ahmedabad    2600000.0
# 7            Online Marketplace for Automobiles          NaN   20000000.0
# 8                                           NaN          NaN          NaN
#
#                          InvestorsName
# 0            People Group (Shaadi.com)
# 1  Hillhouse Capital, Tybourne Capital
# 2     Kalaari Capital, Sequoia Capital
# 3          Asia Pacific Internet Group
# 4                       KARSEMVEN Fund
# 5        Exfinity Fund, GrowX Ventures
# 6                           MakeMyTrip
# 7    UK based Group of Angel Investors
# 8                                  NaN

# %% [markdown]
# ## Check for Missing Values [ isnull(), notnull() ]

# %% [markdown]
# ### isnull() [ pd.Series.isnull(), pd.DataFrame.isnull() ]

# %%
raw_data.isnull()
# Out:
#     Date  StartupName  IndustryVertical  SubVerical  CityLocation  \
# 0  False        False             False       False         False
# 1  False        False             False       False         False
# 2  False        False              True       False         False
# 3  False        False             False        True         False
# 4  False        False             False        True         False
# 5  False        False              True       False          True
# 6  False        False              True       False         False
# 7  False        False             False       False          True
# 8   True         True              True        True          True
#
#    AmountInUSD  InvestorsName
# 0        False          False
# 1         True          False
# 2         True          False
# 3        False          False
# 4        False          False
# 5        False          False
# 6        False          False
# 7        False          False
# 8         True           True

# %%
raw_data.isnull().sum()
# Out:
# Date                1
# StartupName         1
# IndustryVertical    4
# SubVerical          3
# CityLocation        3
# AmountInUSD         3
# InvestorsName       1
# dtype: int64

# %%
raw_data['CityLocation'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7     True
# 8     True
# Name: CityLocation, dtype: bool

# %%
raw_data['CityLocation'].isnull().sum()
# Out:
# 3

# %% [markdown]
# ### isnotnull() [ pd.Series.isnull(), pd.DataFrame.isnull() ]

# %%
raw_data.notnull()
# Out:
#     Date  StartupName  IndustryVertical  SubVerical  CityLocation  \
# 0   True         True              True        True          True
# 1   True         True              True        True          True
# 2   True         True             False        True          True
# 3   True         True              True       False          True
# 4   True         True              True       False          True
# 5   True         True             False        True         False
# 6   True         True             False        True          True
# 7   True         True              True        True         False
# 8  False        False             False       False         False
#
#    AmountInUSD  InvestorsName
# 0         True           True
# 1        False           True
# 2        False           True
# 3         True           True
# 4         True           True
# 5         True           True
# 6         True           True
# 7         True           True
# 8        False          False

# %%
raw_data['AmountInUSD'].notnull()
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8    False
# Name: AmountInUSD, dtype: bool

# %% [markdown]
# ## Handling Missing value [dropna(), fillna(), replace()]

# %% [markdown]
# ### dropna() [ pd.Series.drop(), pd.DataFrame.drop ]

# %% [markdown]
# **Drop missing observations**

# %%
no_missing_value_data = raw_data.dropna()
display(no_missing_value_data)
# Out:
#          Date StartupName IndustryVertical                SubVerical  \
# 0  01/08/2017    TouchKin       Technology  Predicitve Care Platform
#
#   CityLocation  AmountInUSD              InvestorsName
# 0    Bangalore    1300000.0  People Group (Shaadi.com)

# %%
no_missing_value_data.isnull().sum()
# Out:
# Date                0
# StartupName         0
# IndustryVertical    0
# SubVerical          0
# CityLocation        0
# AmountInUSD         0
# InvestorsName       0
# dtype: int64

# %% [markdown]
# **Drop row if they only contain missing values**

# %%
raw_data.dropna(how='all')
# Out:
#          Date       StartupName   IndustryVertical  \
# 0  01/08/2017          TouchKin         Technology
# 1  02/08/2017           Ethinos         TEchnology
# 2  02/08/2017      Leverage Edu                NaN
# 3  02/08/2017              Zepo    ConsumeInternet
# 4  02/08/2017      Click2Clunic  Consumer Internet
# 5  01/08/2017     Billion Loans                NaN
# 6  03/07/2017  Ecolobriumenergy                NaN
# 7  04/07/2017             Droom          eCommerce
#
#                                      SubVerical CityLocation  AmountInUSD  \
# 0                      Predicitve Care Platform    Bangalore    1300000.0
# 1                      Digital Marketing Agency       Mumbai          NaN
# 2  Online Platform for Higher Education Service    New Delhi          NaN
# 3                                           NaN       Mumbai     500000.0
# 4                                           NaN    Hyderabad     850000.0
# 5                Peer to Peer Lenading Platform          NaN    1000000.0
# 6          Energy Management Solutions Provider    Ahmedabad    2600000.0
# 7            Online Marketplace for Automobiles          NaN   20000000.0
#
#                          InvestorsName
# 0            People Group (Shaadi.com)
# 1  Hillhouse Capital, Tybourne Capital
# 2     Kalaari Capital, Sequoia Capital
# 3          Asia Pacific Internet Group
# 4                       KARSEMVEN Fund
# 5        Exfinity Fund, GrowX Ventures
# 6                           MakeMyTrip
# 7    UK based Group of Angel Investors

# %%
raw_data.dropna(axis = 0, how = 'all')
# Out:
#          Date       StartupName   IndustryVertical  \
# 0  01/08/2017          TouchKin         Technology
# 1  02/08/2017           Ethinos         TEchnology
# 2  02/08/2017      Leverage Edu                NaN
# 3  02/08/2017              Zepo    ConsumeInternet
# 4  02/08/2017      Click2Clunic  Consumer Internet
# 5  01/08/2017     Billion Loans                NaN
# 6  03/07/2017  Ecolobriumenergy                NaN
# 7  04/07/2017             Droom          eCommerce
#
#                                      SubVerical CityLocation  AmountInUSD  \
# 0                      Predicitve Care Platform    Bangalore    1300000.0
# 1                      Digital Marketing Agency       Mumbai          NaN
# 2  Online Platform for Higher Education Service    New Delhi          NaN
# 3                                           NaN       Mumbai     500000.0
# 4                                           NaN    Hyderabad     850000.0
# 5                Peer to Peer Lenading Platform          NaN    1000000.0
# 6          Energy Management Solutions Provider    Ahmedabad    2600000.0
# 7            Online Marketplace for Automobiles          NaN   20000000.0
#
#                          InvestorsName
# 0            People Group (Shaadi.com)
# 1  Hillhouse Capital, Tybourne Capital
# 2     Kalaari Capital, Sequoia Capital
# 3          Asia Pacific Internet Group
# 4                       KARSEMVEN Fund
# 5        Exfinity Fund, GrowX Ventures
# 6                           MakeMyTrip
# 7    UK based Group of Angel Investors

# %% [markdown]
# **Drop column if they only contain missing values**
#   * Create a new column full of missing values

# %%
raw_data['Remarks'] = np.nan
display(raw_data)
# Out:
#          Date       StartupName   IndustryVertical  \
# 0  01/08/2017          TouchKin         Technology
# 1  02/08/2017           Ethinos         TEchnology
# 2  02/08/2017      Leverage Edu                NaN
# 3  02/08/2017              Zepo    ConsumeInternet
# 4  02/08/2017      Click2Clunic  Consumer Internet
# 5  01/08/2017     Billion Loans                NaN
# 6  03/07/2017  Ecolobriumenergy                NaN
# 7  04/07/2017             Droom          eCommerce
# 8         NaN               NaN                NaN
#
#                                      SubVerical CityLocation  AmountInUSD  \
# 0                      Predicitve Care Platform    Bangalore    1300000.0
# 1                      Digital Marketing Agency       Mumbai          NaN
# 2  Online Platform for Higher Education Service    New Delhi          NaN
# 3                                           NaN       Mumbai     500000.0
# 4                                           NaN    Hyderabad     850000.0
# 5                Peer to Peer Lenading Platform          NaN    1000000.0
# 6          Energy Management Solutions Provider    Ahmedabad    2600000.0
# 7            Online Marketplace for Automobiles          NaN   20000000.0
# 8                                           NaN          NaN          NaN
#
#                          InvestorsName  Remarks
# 0            People Group (Shaadi.com)      NaN
# 1  Hillhouse Capital, Tybourne Capital      NaN
# 2     Kalaari Capital, Sequoia Capital      NaN
# 3          Asia Pacific Internet Group      NaN
# 4                       KARSEMVEN Fund      NaN
# 5        Exfinity Fund, GrowX Ventures      NaN
# 6                           MakeMyTrip      NaN
# 7    UK based Group of Angel Investors      NaN
# 8                                  NaN      NaN

# %% [markdown]
#  * Drop column if they only contain missing values

# %%
raw_data.dropna(axis=1,how = 'all')
# Out:
#          Date       StartupName   IndustryVertical  \
# 0  01/08/2017          TouchKin         Technology
# 1  02/08/2017           Ethinos         TEchnology
# 2  02/08/2017      Leverage Edu                NaN
# 3  02/08/2017              Zepo    ConsumeInternet
# 4  02/08/2017      Click2Clunic  Consumer Internet
# 5  01/08/2017     Billion Loans                NaN
# 6  03/07/2017  Ecolobriumenergy                NaN
# 7  04/07/2017             Droom          eCommerce
# 8         NaN               NaN                NaN
#
#                                      SubVerical CityLocation  AmountInUSD  \
# 0                      Predicitve Care Platform    Bangalore    1300000.0
# 1                      Digital Marketing Agency       Mumbai          NaN
# 2  Online Platform for Higher Education Service    New Delhi          NaN
# 3                                           NaN       Mumbai     500000.0
# 4                                           NaN    Hyderabad     850000.0
# 5                Peer to Peer Lenading Platform          NaN    1000000.0
# 6          Energy Management Solutions Provider    Ahmedabad    2600000.0
# 7            Online Marketplace for Automobiles          NaN   20000000.0
# 8                                           NaN          NaN          NaN
#
#                          InvestorsName
# 0            People Group (Shaadi.com)
# 1  Hillhouse Capital, Tybourne Capital
# 2     Kalaari Capital, Sequoia Capital
# 3          Asia Pacific Internet Group
# 4                       KARSEMVEN Fund
# 5        Exfinity Fund, GrowX Ventures
# 6                           MakeMyTrip
# 7    UK based Group of Angel Investors
# 8                                  NaN

# %% [markdown]
# **Drop row & column  if they only contain missing values**

# %%
display(raw_data)
# Out:
#          Date       StartupName   IndustryVertical  \
# 0  01/08/2017          TouchKin         Technology
# 1  02/08/2017           Ethinos         TEchnology
# 2  02/08/2017      Leverage Edu                NaN
# 3  02/08/2017              Zepo    ConsumeInternet
# 4  02/08/2017      Click2Clunic  Consumer Internet
# 5  01/08/2017     Billion Loans                NaN
# 6  03/07/2017  Ecolobriumenergy                NaN
# 7  04/07/2017             Droom          eCommerce
# 8         NaN               NaN                NaN
#
#                                      SubVerical CityLocation  AmountInUSD  \
# 0                      Predicitve Care Platform    Bangalore    1300000.0
# 1                      Digital Marketing Agency       Mumbai          NaN
# 2  Online Platform for Higher Education Service    New Delhi          NaN
# 3                                           NaN       Mumbai     500000.0
# 4                                           NaN    Hyderabad     850000.0
# 5                Peer to Peer Lenading Platform          NaN    1000000.0
# 6          Energy Management Solutions Provider    Ahmedabad    2600000.0
# 7            Online Marketplace for Automobiles          NaN   20000000.0
# 8                                           NaN          NaN          NaN
#
#                          InvestorsName  Remarks
# 0            People Group (Shaadi.com)      NaN
# 1  Hillhouse Capital, Tybourne Capital      NaN
# 2     Kalaari Capital, Sequoia Capital      NaN
# 3          Asia Pacific Internet Group      NaN
# 4                       KARSEMVEN Fund      NaN
# 5        Exfinity Fund, GrowX Ventures      NaN
# 6                           MakeMyTrip      NaN
# 7    UK based Group of Angel Investors      NaN
# 8                                  NaN      NaN

# %%
raw_data.dropna(axis=[0,1],how='all')
# Out:
#          Date       StartupName   IndustryVertical  \
# 0  01/08/2017          TouchKin         Technology
# 1  02/08/2017           Ethinos         TEchnology
# 2  02/08/2017      Leverage Edu                NaN
# 3  02/08/2017              Zepo    ConsumeInternet
# 4  02/08/2017      Click2Clunic  Consumer Internet
# 5  01/08/2017     Billion Loans                NaN
# 6  03/07/2017  Ecolobriumenergy                NaN
# 7  04/07/2017             Droom          eCommerce
#
#                                      SubVerical CityLocation  AmountInUSD  \
# 0                      Predicitve Care Platform    Bangalore    1300000.0
# 1                      Digital Marketing Agency       Mumbai          NaN
# 2  Online Platform for Higher Education Service    New Delhi          NaN
# 3                                           NaN       Mumbai     500000.0
# 4                                           NaN    Hyderabad     850000.0
# 5                Peer to Peer Lenading Platform          NaN    1000000.0
# 6          Energy Management Solutions Provider    Ahmedabad    2600000.0
# 7            Online Marketplace for Automobiles          NaN   20000000.0
#
#                          InvestorsName
# 0            People Group (Shaadi.com)
# 1  Hillhouse Capital, Tybourne Capital
# 2     Kalaari Capital, Sequoia Capital
# 3          Asia Pacific Internet Group
# 4                       KARSEMVEN Fund
# 5        Exfinity Fund, GrowX Ventures
# 6                           MakeMyTrip
# 7    UK based Group of Angel Investors

# %% [markdown]
# ** Drop rows that contain less than 6 observations**

# %%
display(raw_data)
# Out:
#          Date       StartupName   IndustryVertical  \
# 0  01/08/2017          TouchKin         Technology
# 1  02/08/2017           Ethinos         TEchnology
# 2  02/08/2017      Leverage Edu                NaN
# 3  02/08/2017              Zepo    ConsumeInternet
# 4  02/08/2017      Click2Clunic  Consumer Internet
# 5  01/08/2017     Billion Loans                NaN
# 6  03/07/2017  Ecolobriumenergy                NaN
# 7  04/07/2017             Droom          eCommerce
# 8         NaN               NaN                NaN
#
#                                      SubVerical CityLocation  AmountInUSD  \
# 0                      Predicitve Care Platform    Bangalore    1300000.0
# 1                      Digital Marketing Agency       Mumbai          NaN
# 2  Online Platform for Higher Education Service    New Delhi          NaN
# 3                                           NaN       Mumbai     500000.0
# 4                                           NaN    Hyderabad     850000.0
# 5                Peer to Peer Lenading Platform          NaN    1000000.0
# 6          Energy Management Solutions Provider    Ahmedabad    2600000.0
# 7            Online Marketplace for Automobiles          NaN   20000000.0
# 8                                           NaN          NaN          NaN
#
#                          InvestorsName  Remarks
# 0            People Group (Shaadi.com)      NaN
# 1  Hillhouse Capital, Tybourne Capital      NaN
# 2     Kalaari Capital, Sequoia Capital      NaN
# 3          Asia Pacific Internet Group      NaN
# 4                       KARSEMVEN Fund      NaN
# 5        Exfinity Fund, GrowX Ventures      NaN
# 6                           MakeMyTrip      NaN
# 7    UK based Group of Angel Investors      NaN
# 8                                  NaN      NaN

# %%
raw_data.dropna(thresh=6)
# Out:
#          Date       StartupName   IndustryVertical  \
# 0  01/08/2017          TouchKin         Technology
# 1  02/08/2017           Ethinos         TEchnology
# 3  02/08/2017              Zepo    ConsumeInternet
# 4  02/08/2017      Click2Clunic  Consumer Internet
# 6  03/07/2017  Ecolobriumenergy                NaN
# 7  04/07/2017             Droom          eCommerce
#
#                              SubVerical CityLocation  AmountInUSD  \
# 0              Predicitve Care Platform    Bangalore    1300000.0
# 1              Digital Marketing Agency       Mumbai          NaN
# 3                                   NaN       Mumbai     500000.0
# 4                                   NaN    Hyderabad     850000.0
# 6  Energy Management Solutions Provider    Ahmedabad    2600000.0
# 7    Online Marketplace for Automobiles          NaN   20000000.0
#
#                          InvestorsName  Remarks
# 0            People Group (Shaadi.com)      NaN
# 1  Hillhouse Capital, Tybourne Capital      NaN
# 3          Asia Pacific Internet Group      NaN
# 4                       KARSEMVEN Fund      NaN
# 6                           MakeMyTrip      NaN
# 7    UK based Group of Angel Investors      NaN

# %% [markdown]
# ### fillna() [ pd.Series.drop(), pd.DataFrame.drop ]

# %% [markdown]
# ** Fill in missing data with zeros**

# %%
raw_data.fillna(0)
# Out:
#          Date       StartupName   IndustryVertical  \
# 0  01/08/2017          TouchKin         Technology
# 1  02/08/2017           Ethinos         TEchnology
# 2  02/08/2017      Leverage Edu                  0
# 3  02/08/2017              Zepo    ConsumeInternet
# 4  02/08/2017      Click2Clunic  Consumer Internet
# 5  01/08/2017     Billion Loans                  0
# 6  03/07/2017  Ecolobriumenergy                  0
# 7  04/07/2017             Droom          eCommerce
# 8           0                 0                  0
#
#                                      SubVerical CityLocation  AmountInUSD  \
# 0                      Predicitve Care Platform    Bangalore    1300000.0
# 1                      Digital Marketing Agency       Mumbai          0.0
# 2  Online Platform for Higher Education Service    New Delhi          0.0
# 3                                             0       Mumbai     500000.0
# 4                                             0    Hyderabad     850000.0
# 5                Peer to Peer Lenading Platform            0    1000000.0
# 6          Energy Management Solutions Provider    Ahmedabad    2600000.0
# 7            Online Marketplace for Automobiles            0   20000000.0
# 8                                             0            0          0.0
#
#                          InvestorsName  Remarks
# 0            People Group (Shaadi.com)      0.0
# 1  Hillhouse Capital, Tybourne Capital      0.0
# 2     Kalaari Capital, Sequoia Capital      0.0
# 3          Asia Pacific Internet Group      0.0
# 4                       KARSEMVEN Fund      0.0
# 5        Exfinity Fund, GrowX Ventures      0.0
# 6                           MakeMyTrip      0.0
# 7    UK based Group of Angel Investors      0.0
# 8                                    0      0.0

# %% [markdown]
# **Fill in missing  with some value**

# %%
raw_data['Remarks'].fillna('Missed Remark',inplace=True)
display(raw_data)
# Out:
#          Date       StartupName   IndustryVertical  \
# 0  01/08/2017          TouchKin         Technology
# 1  02/08/2017           Ethinos         TEchnology
# 2  02/08/2017      Leverage Edu                NaN
# 3  02/08/2017              Zepo    ConsumeInternet
# 4  02/08/2017      Click2Clunic  Consumer Internet
# 5  01/08/2017     Billion Loans                NaN
# 6  03/07/2017  Ecolobriumenergy                NaN
# 7  04/07/2017             Droom          eCommerce
# 8         NaN               NaN                NaN
#
#                                      SubVerical CityLocation  AmountInUSD  \
# 0                      Predicitve Care Platform    Bangalore    1300000.0
# 1                      Digital Marketing Agency       Mumbai          NaN
# 2  Online Platform for Higher Education Service    New Delhi          NaN
# 3                                           NaN       Mumbai     500000.0
# 4                                           NaN    Hyderabad     850000.0
# 5                Peer to Peer Lenading Platform          NaN    1000000.0
# 6          Energy Management Solutions Provider    Ahmedabad    2600000.0
# 7            Online Marketplace for Automobiles          NaN   20000000.0
# 8                                           NaN          NaN          NaN
#
#                          InvestorsName        Remarks
# 0            People Group (Shaadi.com)  Missed Remark
# 1  Hillhouse Capital, Tybourne Capital  Missed Remark
# 2     Kalaari Capital, Sequoia Capital  Missed Remark
# 3          Asia Pacific Internet Group  Missed Remark
# 4                       KARSEMVEN Fund  Missed Remark
# 5        Exfinity Fund, GrowX Ventures  Missed Remark
# 6                           MakeMyTrip  Missed Remark
# 7    UK based Group of Angel Investors  Missed Remark
# 8                                  NaN  Missed Remark

# %% [markdown]
# **Fill in missing with forward(ffill/pad) value**

# %%
raw_data['AmountInUSD'].fillna(method ='pad')
# Out:
# 0     1300000.0
# 1     1300000.0
# 2     1300000.0
# 3      500000.0
# 4      850000.0
# 5     1000000.0
# 6     2600000.0
# 7    20000000.0
# 8    20000000.0
# Name: AmountInUSD, dtype: float64

# %% [markdown]
# **Fill in missing with backword(ffill/pad) value**

# %%
raw_data['AmountInUSD'].fillna(method = 'bfill')
# Out:
# 0     1300000.0
# 1      500000.0
# 2      500000.0
# 3      500000.0
# 4      850000.0
# 5     1000000.0
# 6     2600000.0
# 7    20000000.0
# 8           NaN
# Name: AmountInUSD, dtype: float64

# %% [markdown]
# **Fill in missing with ffill/bfill value by limit**

# %%
raw_data['AmountInUSD'].fillna(method = 'ffill',limit=1)
# Out:
# 0     1300000.0
# 1     1300000.0
# 2           NaN
# 3      500000.0
# 4      850000.0
# 5     1000000.0
# 6     2600000.0
# 7    20000000.0
# 8    20000000.0
# Name: AmountInUSD, dtype: float64

# %% [markdown]
# **Select some raws but ignore the missing data points**

# %%
raw_data[raw_data['StartupName'].notnull() & raw_data['AmountInUSD'] & raw_data['InvestorsName'].notnull() ]
# Out:
#          Date       StartupName   IndustryVertical  \
# 0  01/08/2017          TouchKin         Technology
# 3  02/08/2017              Zepo    ConsumeInternet
# 4  02/08/2017      Click2Clunic  Consumer Internet
# 5  01/08/2017     Billion Loans                NaN
# 6  03/07/2017  Ecolobriumenergy                NaN
# 7  04/07/2017             Droom          eCommerce
#
#                              SubVerical CityLocation  AmountInUSD  \
# 0              Predicitve Care Platform    Bangalore    1300000.0
# 3                                   NaN       Mumbai     500000.0
# 4                                   NaN    Hyderabad     850000.0
# 5        Peer to Peer Lenading Platform          NaN    1000000.0
# 6  Energy Management Solutions Provider    Ahmedabad    2600000.0
# 7    Online Marketplace for Automobiles          NaN   20000000.0
#
#                        InvestorsName        Remarks
# 0          People Group (Shaadi.com)  Missed Remark
# 3        Asia Pacific Internet Group  Missed Remark
# 4                     KARSEMVEN Fund  Missed Remark
# 5      Exfinity Fund, GrowX Ventures  Missed Remark
# 6                         MakeMyTrip  Missed Remark
# 7  UK based Group of Angel Investors  Missed Remark

# %% [markdown]
# ### replace[ pd.Series.drop(), pd.DataFrame.drop ]

# %% [markdown]
# ** Replace missing with some value**

# %%
raw_data['IndustryVertical'].replace(to_replace = np.nan, value = 'Technology')
# Out:
# 0           Technology
# 1           TEchnology
# 2           Technology
# 3      ConsumeInternet
# 4    Consumer Internet
# 5           Technology
# 6           Technology
# 7            eCommerce
# 8           Technology
# Name: IndustryVertical, dtype: object
